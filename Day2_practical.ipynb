# %% [markdown]
# # Basic python: Assignment 2
#
# Remember, this practical is not assessed, but you should still comment your code and make it as good as you can. This practical also fulfils the key learning objective to analyse and plot a physiological signal.
#
# I have added the tasks from the Practical2_instructions document to this notebook with cells in-between where you can fill in the code. For the first few I've provided hints, then the rest is up to you!
#
# ## First up!
# Make a copy of this notebook and save it in your own Google Drive. (File -> Save a copy in Drive)

# %% [markdown]
# ## Task 1
# Find the folder containing respiration data, it should be called “breathing_data” and contain 18 csv files
#
# Like yesterday:
#
# Go to the link: https://drive.google.com/drive/folders/1tZJQV0d0zktA1v-y-fvJiMAFN14mP9SH?usp=sharing and click on "add the shortcut to My Drive" in the drop down menu. This will add the shortcut to your Google Drive (if you hadn't already added it for Day 1's practical)

# %%
# now run this line! It'll copy the data required for today's practical from your google drive to this colab instance.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cp -r drive/MyDrive/CBRP_2023_python_course_data/Day2/* .
# Out:
# Mounted at /content/drive

# %% [markdown]
# You should now be able to see the breathing_data folder in the file explorer to the left!

# %% [markdown]
# ## Task 2
# Load the required modules. These include, but are not limited to numpy, matplotlib.pyplot and find_peaks from scipy.signal

# %%
# Set up the plotting - the line starting with % is a notebook specific thing
% matplotlib inline
import matplotlib.pyplot as plt
# Import numpy - I recommend shortening it to np
import numpy as np
import ... # over to you from here

# %% [markdown]
# ## Task 3
# Use numpy.loadtxt to load the first csv file. Check the documentation for this function to figure out how to load a csv. What is the shape of the resulting array? What does the shape mean?

# %%
file_path = "./breathing_data/p01.csv"

# %% [markdown]
# ## Task 4
# Try plotting the data using a few different options (e.g. plot, scatter). What does each axis in the array refer to?

# %% [markdown]
# ## Task 5
# The data is probably quite noisy. To remove the noise, convolve the signal with a filter function by using numpy.convolve. There are some example filter functions in the PythonBasics.ipynb notebook, or you could try writing something of your own.

# %% [markdown]
# ## Task 6
# Identify the peaks in the signal. You can use find_peaks from scipy, or implement something of your own. There is a broken implementation in the PythonBasics.ipynb notebook, see if you can figure out what is wrong and fix it.

# %% [markdown]
# ## Task 7
# Now, plot the original signal, the smoothed signal and some markers identifying the location of peaks. Make sure that:
# - Your axes are labelled
# - There is a legend
# - You can see all the plot lines

# %% [markdown]
# ## Task 8
# Save the figure in .png format

# %% [markdown]
# The .png image can be moved from the colab session storage to your google drive using the command below. You will need to change the file name (currently "coffee.jpg") to match your image's file name.

# %%
# %cp coffee.jpg drive/MyDrive/

# %% [markdown]
# ## Task 9
# Now you have this working for one csv file, try to apply it to the other 17 files. Produce a png showing the original signal, smoothed signal and detected peaks for each one. Try to automate this process, for example by using the functions in the os module to list files in a folder.

# %% [markdown]
# ## Task 10
# By looking at the peak-to-peak interval, you should be able to work out the respiration rate for each csv file. Which one has the highest? Are there any that are weird, can you figure out how to exclude sections of the data to improve the respiration rate estimation?
